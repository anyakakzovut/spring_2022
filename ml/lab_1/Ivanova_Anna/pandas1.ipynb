# %%
import pandas as pd
my_series = pd.Series([5, 6, 7, 8, 9, 10])
my_series
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    10
# dtype: int64

# %%
my_series.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
my_series.values
# Out:
# array([ 5,  6,  7,  8,  9, 10], dtype=int64)

# %%
my_series[4]
# Out:
# 9

# %%
my_series2 = pd.Series([5, 6, 7, 8, 9, 10], index=['a', 'b', 'c', 'd', 'e', 'f'])
my_series2['f']
# Out:
# 10

# %%
my_series2[['a', 'b', 'f']]
# Out:
# a     5
# b     6
# f    10
# dtype: int64

# %%
my_series2[['a', 'b' , 'f']] = 0
my_series2
# Out:
# a    0
# b    0
# c    7
# d    8
# e    9
# f    0
# dtype: int64

# %%
my_series2[my_series2 > 0]
# Out:
# c    7
# d    8
# e    9
# dtype: int64

# %%
my_series2[my_series2 > 0] * 2
# Out:
# c    14
# d    16
# e    18
# dtype: int64

# %%
my_series3 = pd.Series({'a': 5, 'b': 6, 'c': 7, 'd': 8})
my_series3
# Out:
# a    5
# b    6
# c    7
# d    8
# dtype: int64

# %%
my_series3.name = 'numbers'
my_series3.index.name = 'letters'
my_series3
# Out:
# letters
# a    5
# b    6
# c    7
# d    8
# Name: numbers, dtype: int64

# %%
my_series3.index = ['A', 'B', 'C', 'D']
my_series3
# Out:
# A    5
# B    6
# C    7
# D    8
# Name: numbers, dtype: int64

# %%
df = pd.DataFrame({
    'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
    'population': [17.04, 143.5, 9.5, 45.5],
    'square': [2724902, 17125191, 207600, 603628]
})
df
# Out:
#       country  population    square
# 0  Kazakhstan       17.04   2724902
# 1      Russia      143.50  17125191
# 2     Belarus        9.50    207600
# 3     Ukraine       45.50    603628

# %%
df['country']
# Out:
# 0    Kazakhstan
# 1        Russia
# 2       Belarus
# 3       Ukraine
# Name: country, dtype: object

# %%
df.columns
# Out:
# Index(['country', 'population', 'square'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df = pd.DataFrame({
    'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
    'population': [17.04, 143.5, 9.5, 45.5],
    'square':[2724902, 17125191, 207600, 603628]
}, index=['KZ', 'RU', 'BY', 'UA'])
df
# Out:
#        country  population    square
# KZ  Kazakhstan       17.04   2724902
# RU      Russia      143.50  17125191
# BY     Belarus        9.50    207600
# UA     Ukraine       45.50    603628

# %%
df.index = ['KZ', 'RU', 'BY', 'UA']
df.index.name = 'Country Code'
df
# Out:
#                  country  population    square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# UA               Ukraine       45.50    603628

# %%
df['country']
# Out:
# Country Code
# KZ    Kazakhstan
# RU        Russia
# BY       Belarus
# UA       Ukraine
# Name: country, dtype: object

# %%
df.loc['KZ']
# Out:
# country       Kazakhstan
# population         17.04
# square           2724902
# Name: KZ, dtype: object

# %%
df.iloc[0]
# Out:
# country       Kazakhstan
# population         17.04
# square           2724902
# Name: KZ, dtype: object

# %%
df.loc[['KZ', 'RU'], 'population']
# Out:
# Country Code
# KZ     17.04
# RU    143.50
# Name: population, dtype: float64

# %%
df.loc['KZ':'BY', :]
# Out:
#                  country  population    square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600

# %%
df[df.population > 10][['country', 'square']]
# Out:
#                  country    square
# Country Code
# KZ            Kazakhstan   2724902
# RU                Russia  17125191
# UA               Ukraine    603628

# %%
df.reset_index()
# Out:
#   Country Code     country  population    square
# 0           KZ  Kazakhstan       17.04   2724902
# 1           RU      Russia      143.50  17125191
# 2           BY     Belarus        9.50    207600
# 3           UA     Ukraine       45.50    603628

# %%
df['density'] = df['population'] / df['square'] * 1000000
df
# Out:
#                  country  population    square    density
# Country Code
# KZ            Kazakhstan       17.04   2724902   6.253436
# RU                Russia      143.50  17125191   8.379469
# BY               Belarus        9.50    207600  45.761079
# UA               Ukraine       45.50    603628  75.377550

# %%
df.drop(['density'], axis='columns')
# Out:
#                  country  population    square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# UA               Ukraine       45.50    603628

# %%
df = df.rename(columns={'Country Code': 'country_code'})
df
# Out:
#                  country  population    square    density
# Country Code
# KZ            Kazakhstan       17.04   2724902   6.253436
# RU                Russia      143.50  17125191   8.379469
# BY               Belarus        9.50    207600  45.761079
# UA               Ukraine       45.50    603628  75.377550

# %%
titanic_df = pd.read_csv('titanic3.csv', sep = ';')
print(titanic_df.head())
# Out:
#    pclass  passengerId  survived  \
# 0       1            1         1
# 1       1            2         1
# 2       1            3         0
# 3       1            4         0
# 4       1            5         0
#
#                                               name     sex      age  sibsp  \
# 0                    Allen, Miss, Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master, Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss, Helen Loraine  female   2.0000      1
# 3             Allison, Mr, Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs, Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  211.3375       B5        S    2    NaN
# 1      2  113781    151.55  C22 C26        S   11    NaN
# 2      2  113781    151.55  C22 C26        S  NaN    NaN
# 3      2  113781    151.55  C22 C26        S  NaN  135.0
# 4      2  113781    151.55  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis. MO
# 1  Montreal. PQ / Chesterville. ON
# 2  Montreal. PQ / Chesterville. ON
# 3  Montreal. PQ / Chesterville. ON
# 4  Montreal. PQ / Chesterville. ON

# %%
print(titanic_df.groupby(['sex', 'survived'])['passengerId'].count())
# Out:
# sex     survived
# female  0           127
#         1           339
# male    0           682
#         1           161
# Name: passengerId, dtype: int64

# %%
print(titanic_df.groupby(['pclass', 'survived'])['passengerId'].count())
# Out:
# pclass  survived
# 1       0           123
#         1           200
# 2       0           158
#         1           119
# 3       0           528
#         1           181
# Name: passengerId, dtype: int64

# %%
import pandas as pd
# %matplotlib inline

# %%
pass_data = pd.read_csv('titanic3.csv', sep = ';')
pass_data
# Out:
#       pclass  passengerId  survived  \
# 0          1            1         1
# 1          1            2         1
# 2          1            3         0
# 3          1            4         0
# 4          1            5         0
# ...      ...          ...       ...
# 1304       3         1305         0
# 1305       3         1306         0
# 1306       3         1307         0
# 1307       3         1308         0
# 1308       3         1309         0
#
#                                                  name     sex         age  \
# 0                       Allen, Miss, Elisabeth Walton  female     29.0000
# 1                      Allison, Master, Hudson Trevor    male      0.9167
# 2                        Allison, Miss, Helen Loraine  female      2.0000
# 3                Allison, Mr, Hudson Joshua Creighton    male     30.0000
# 4     Allison, Mrs, Hudson J C (Bessie Waldo Daniels)  female     25.0000
# ...                                               ...     ...         ...
# 1304                             Zabour, Miss, Hileni  female  44695.0000
# 1305                            Zabour, Miss, Thamine  female         NaN
# 1306                        Zakarian, Mr, Mapriededer    male  44707.0000
# 1307                              Zakarian, Mr, Ortin    male     27.0000
# 1308                               Zimmerman, Mr, Leo    male     29.0000
#
#       sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0         0      0   24160  211.3375       B5        S    2    NaN
# 1         1      2  113781    151.55  C22 C26        S   11    NaN
# 2         1      2  113781    151.55  C22 C26        S  NaN    NaN
# 3         1      2  113781    151.55  C22 C26        S  NaN  135.0
# 4         1      2  113781    151.55  C22 C26        S  NaN    NaN
# ...     ...    ...     ...       ...      ...      ...  ...    ...
# 1304      1      0    2665   14.4542      NaN        C  NaN  328.0
# 1305      1      0    2665   14.4542      NaN        C  NaN    NaN
# 1306      0      0    2656     7.225      NaN        C  NaN  304.0
# 1307      0      0    2670     7.225      NaN        C  NaN    NaN
# 1308      0      0  315082     7.875      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis. MO
# 1     Montreal. PQ / Chesterville. ON
# 2     Montreal. PQ / Chesterville. ON
# 3     Montreal. PQ / Chesterville. ON
# 4     Montreal. PQ / Chesterville. ON
# ...                               ...
# 1304                              NaN
# 1305                              NaN
# 1306                              NaN
# 1307                              NaN
# 1308                              NaN
#
# [1309 rows x 15 columns]

# %%
pass_data.head(3)
# Out:
#    pclass  passengerId  survived                            name     sex  \
# 0       1            1         1   Allen, Miss, Elisabeth Walton  female
# 1       1            2         1  Allison, Master, Hudson Trevor    male
# 2       1            3         0    Allison, Miss, Helen Loraine  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat  body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2   NaN
# 1   0.9167      1      2  113781    151.55  C22 C26        S   11   NaN
# 2   2.0000      1      2  113781    151.55  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis. MO
# 1  Montreal. PQ / Chesterville. ON
# 2  Montreal. PQ / Chesterville. ON

# %%
pass_data.columns
# Out:
# Index(['pclass', 'passengerId', 'survived', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest'],
#       dtype='object')

# %%
pass_data[2:5]
# Out:
#    pclass  passengerId  survived  \
# 2       1            3         0
# 3       1            4         0
# 4       1            5         0
#
#                                               name     sex   age  sibsp  \
# 2                     Allison, Miss, Helen Loraine  female   2.0      1
# 3             Allison, Mr, Hudson Joshua Creighton    male  30.0      1
# 4  Allison, Mrs, Hudson J C (Bessie Waldo Daniels)  female  25.0      1
#
#    parch  ticket    fare    cabin embarked boat   body  \
# 2      2  113781  151.55  C22 C26        S  NaN    NaN
# 3      2  113781  151.55  C22 C26        S  NaN  135.0
# 4      2  113781  151.55  C22 C26        S  NaN    NaN
#
#                          home.dest
# 2  Montreal. PQ / Chesterville. ON
# 3  Montreal. PQ / Chesterville. ON
# 4  Montreal. PQ / Chesterville. ON

# %%
pass_data.iloc[1:5, 2:4]
# Out:
#    survived                                             name
# 1         1                   Allison, Master, Hudson Trevor
# 2         0                     Allison, Miss, Helen Loraine
# 3         0             Allison, Mr, Hudson Joshua Creighton
# 4         0  Allison, Mrs, Hudson J C (Bessie Waldo Daniels)

# %%
pass_data['name'].head()
# Out:
# 0                      Allen, Miss, Elisabeth Walton
# 1                     Allison, Master, Hudson Trevor
# 2                       Allison, Miss, Helen Loraine
# 3               Allison, Mr, Hudson Joshua Creighton
# 4    Allison, Mrs, Hudson J C (Bessie Waldo Daniels)
# Name: name, dtype: object

# %%
pass_data[['name', 'sex', 'parch']].head()
# Out:
#                                               name     sex  parch
# 0                    Allen, Miss, Elisabeth Walton  female      0
# 1                   Allison, Master, Hudson Trevor    male      2
# 2                     Allison, Miss, Helen Loraine  female      2
# 3             Allison, Mr, Hudson Joshua Creighton    male      2
# 4  Allison, Mrs, Hudson J C (Bessie Waldo Daniels)  female      2

# %%
pass_data[pass_data['sex'] == 'female'].head()
# Out:
#    pclass  passengerId  survived  \
# 0       1            1         1
# 2       1            3         0
# 4       1            5         0
# 6       1            7         1
# 8       1            9         1
#
#                                               name     sex   age  sibsp  \
# 0                    Allen, Miss, Elisabeth Walton  female  29.0      0
# 2                     Allison, Miss, Helen Loraine  female   2.0      1
# 4  Allison, Mrs, Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# 6                Andrews, Miss, Kornelia Theodosia  female  63.0      1
# 8    Appleton, Mrs, Edward Dale (Charlotte Lamson)  female  53.0      2
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 2      2  113781    151.55  C22 C26        S  NaN   NaN
# 4      2  113781    151.55  C22 C26        S  NaN   NaN
# 6      0   13502   77.9583       D7        S   10   NaN
# 8      0   11769   51.4792     C101        S    D   NaN
#
#                          home.dest
# 0                     St Louis. MO
# 2  Montreal. PQ / Chesterville. ON
# 4  Montreal. PQ / Chesterville. ON
# 6                       Hudson. NY
# 8              Bayside. Queens. NY

# %%
pass_data[(pass_data['sex'] == 'female') & (pass_data['age'].astype(float) >= 60) | (pass_data['sex'] == 'male')].head()
# Out:
#    pclass  passengerId  survived                                  name  \
# 1       1            2         1        Allison, Master, Hudson Trevor
# 3       1            4         0  Allison, Mr, Hudson Joshua Creighton
# 5       1            6         1                   Anderson, Mr, Harry
# 6       1            7         1     Andrews, Miss, Kornelia Theodosia
# 7       1            8         0                Andrews, Mr, Thomas Jr
#
#       sex      age  sibsp  parch  ticket     fare    cabin embarked boat  \
# 1    male   0.9167      1      2  113781   151.55  C22 C26        S   11
# 3    male  30.0000      1      2  113781   151.55  C22 C26        S  NaN
# 5    male  48.0000      0      0   19952    26.55      E12        S    3
# 6  female  63.0000      1      0   13502  77.9583       D7        S   10
# 7    male  39.0000      0      0  112050        0      A36        S  NaN
#
#     body                        home.dest
# 1    NaN  Montreal. PQ / Chesterville. ON
# 3  135.0  Montreal. PQ / Chesterville. ON
# 5    NaN                     New York. NY
# 6    NaN                       Hudson. NY
# 7    NaN                      Belfast. NI

# %%
pass_data[(pass_data.sex == 'female') & 
          (pass_data.age > 18) &
          (pass_data.age < 25) &
          (pass_data.sibsp == 0) &
          (pass_data.parch == 0)].shape
# Out:
# (40, 15)

# %%
pass_data.age.hist(bins = 30)
# Out:
# <AxesSubplot:>

# %%
pass_data.rename(columns={'sex': 'Sex'}, inplace=True)
pass_data.head()
# Out:
#    pclass  passengerId  survived  \
# 0       1            1         1
# 1       1            2         1
# 2       1            3         0
# 3       1            4         0
# 4       1            5         0
#
#                                               name     Sex      age  sibsp  \
# 0                    Allen, Miss, Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master, Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss, Helen Loraine  female   2.0000      1
# 3             Allison, Mr, Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs, Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  211.3375       B5        S    2    NaN
# 1      2  113781    151.55  C22 C26        S   11    NaN
# 2      2  113781    151.55  C22 C26        S  NaN    NaN
# 3      2  113781    151.55  C22 C26        S  NaN  135.0
# 4      2  113781    151.55  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis. MO
# 1  Montreal. PQ / Chesterville. ON
# 2  Montreal. PQ / Chesterville. ON
# 3  Montreal. PQ / Chesterville. ON
# 4  Montreal. PQ / Chesterville. ON

# %%
def get_last_name(name):
    return name.split(',')[0].strip()

last_names = pass_data['name'].apply(get_last_name)
last_names.head()
# Out:
# 0      Allen
# 1    Allison
# 2    Allison
# 3    Allison
# 4    Allison
# Name: name, dtype: object

# %%
pass_data['Last_name'] = last_names
pass_data.head()
# Out:
#    pclass  passengerId  survived  \
# 0       1            1         1
# 1       1            2         1
# 2       1            3         0
# 3       1            4         0
# 4       1            5         0
#
#                                               name     Sex      age  sibsp  \
# 0                    Allen, Miss, Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master, Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss, Helen Loraine  female   2.0000      1
# 3             Allison, Mr, Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs, Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  211.3375       B5        S    2    NaN
# 1      2  113781    151.55  C22 C26        S   11    NaN
# 2      2  113781    151.55  C22 C26        S  NaN    NaN
# 3      2  113781    151.55  C22 C26        S  NaN  135.0
# 4      2  113781    151.55  C22 C26        S  NaN    NaN
#
#                          home.dest Last_name
# 0                     St Louis. MO     Allen
# 1  Montreal. PQ / Chesterville. ON   Allison
# 2  Montreal. PQ / Chesterville. ON   Allison
# 3  Montreal. PQ / Chesterville. ON   Allison
# 4  Montreal. PQ / Chesterville. ON   Allison

# %%
pass_data.drop('Last_name', axis=1, inplace=True)
pass_data.head()
# Out:
#    pclass  passengerId  survived  \
# 0       1            1         1
# 1       1            2         1
# 2       1            3         0
# 3       1            4         0
# 4       1            5         0
#
#                                               name     Sex      age  sibsp  \
# 0                    Allen, Miss, Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master, Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss, Helen Loraine  female   2.0000      1
# 3             Allison, Mr, Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs, Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  211.3375       B5        S    2    NaN
# 1      2  113781    151.55  C22 C26        S   11    NaN
# 2      2  113781    151.55  C22 C26        S  NaN    NaN
# 3      2  113781    151.55  C22 C26        S  NaN  135.0
# 4      2  113781    151.55  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis. MO
# 1  Montreal. PQ / Chesterville. ON
# 2  Montreal. PQ / Chesterville. ON
# 3  Montreal. PQ / Chesterville. ON
# 4  Montreal. PQ / Chesterville. ON

# %%
pass_data['boat'].isnull().head()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: boat, dtype: bool

# %%
pass_data[pass_data['boat'].notnull()].head()
# Out:
#    pclass  passengerId  survived  \
# 0       1            1         1
# 1       1            2         1
# 5       1            6         1
# 6       1            7         1
# 8       1            9         1
#
#                                             name     Sex      age  sibsp  \
# 0                  Allen, Miss, Elisabeth Walton  female  29.0000      0
# 1                 Allison, Master, Hudson Trevor    male   0.9167      1
# 5                            Anderson, Mr, Harry    male  48.0000      0
# 6              Andrews, Miss, Kornelia Theodosia  female  63.0000      1
# 8  Appleton, Mrs, Edward Dale (Charlotte Lamson)  female  53.0000      2
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781    151.55  C22 C26        S   11   NaN
# 5      0   19952     26.55      E12        S    3   NaN
# 6      0   13502   77.9583       D7        S   10   NaN
# 8      0   11769   51.4792     C101        S    D   NaN
#
#                          home.dest
# 0                     St Louis. MO
# 1  Montreal. PQ / Chesterville. ON
# 5                     New York. NY
# 6                       Hudson. NY
# 8              Bayside. Queens. NY

# %%
pass_data.sort_values(by=['pclass', 'fare'], ascending=True).head()
# Out:
#      pclass  passengerId  survived                                   name  \
# 7         1            8         0                 Andrews, Mr, Thomas Jr
# 70        1           71         0  Chisholm, Mr, Roderick Robert Crispin
# 125       1          126         0                       Fry, Mr, Richard
# 150       1          151         0                  Harrison, Mr, William
# 170       1          171         1                Ismay, Mr, Joseph Bruce
#
#       Sex   age  sibsp  parch  ticket fare        cabin embarked boat   body  \
# 7    male  39.0      0      0  112050    0          A36        S  NaN    NaN
# 70   male   NaN      0      0  112051    0          NaN        S  NaN    NaN
# 125  male   NaN      0      0  112058    0         B102        S  NaN    NaN
# 150  male  40.0      0      0  112059    0          B94        S  NaN  110.0
# 170  male  49.0      0      0  112058    0  B52 B54 B56        S    C    NaN
#
#                         home.dest
# 7                     Belfast. NI
# 70   Liverpool. England / Belfast
# 125                           NaN
# 150                           NaN
# 170                     Liverpool

# %%
pass_data.sort_values(by=['pclass', 'fare'], ascending=[True, False]).head()
# Out:
#      pclass  passengerId  survived  \
# 154       1          155         0
# 155       1          156         1
# 225       1          226         0
# 230       1          231         1
# 26        1           27         1
#
#                                                   name     Sex   age  sibsp  \
# 154                         Hays, Mr, Charles Melville    male  55.0      1
# 155  Hays, Mrs, Charles Melville (Clara Jennings Gr...  female  52.0      1
# 225                         Payne, Mr, Vivian Ponsonby    male  23.0      0
# 230                              Perreault, Miss, Anne  female  30.0      0
# 26                             Bishop, Mr, Dickinson H    male  25.0      1
#
#      parch ticket     fare cabin embarked boat   body     home.dest
# 154      1  12749     93.5   B69        S  NaN  307.0  Montreal. PQ
# 155      1  12749     93.5   B69        S    3    NaN  Montreal. PQ
# 225      0  12749     93.5   B24        S  NaN    NaN  Montreal. PQ
# 230      0  12749     93.5   B73        S    3    NaN           NaN
# 26       0  11967  91.0792   B49        C    7    NaN  Dowagiac. MI

# %%
pass_data.groupby('Sex')

# %%
pass_data.groupby('Sex')['pclass'].value_counts()
# Out:
# Sex     pclass
# female  3         216
#         1         144
#         2         106
# male    3         493
#         1         179
#         2         171
# Name: pclass, dtype: int64

# %%
pass_data.groupby('pclass')['fare'].describe()
# Out:
#        count unique     top freq
# pclass
# 1        323    107   26.55   22
# 2        277     48      13   59
# 3        708    110  июл.58   62

# %%
pass_data.groupby('Sex')['age'].mean()
# Out:
# Sex
# female    374.154854
# male      913.330674
# Name: age, dtype: float64

# %%
pass_data.groupby('Sex')['survived'].mean()
# Out:
# Sex
# female    0.727468
# male      0.190985
# Name: survived, dtype: float64

# %%
pass_data.groupby('pclass')['survived'].mean()
# Out:
# pclass
# 1    0.619195
# 2    0.429603
# 3    0.255289
# Name: survived, dtype: float64

# %%
pass_data.groupby('Sex', as_index=False)['survived'].mean()
# Out:
#       Sex  survived
# 0  female  0.727468
# 1    male  0.190985
